# %% [markdown]
# # Testing the FRED API

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px
import seaborn as sns
import fredapi

plt.style.use('fivethirtyeight')
pd.set_option('display.max_columns', 500)
color_pal = plt.rcParams['axes.prop_cycle'].by_key()['color']

from fredapi import Fred
import os
from dotenv import load_dotenv

load_dotenv()

# Initialize the FRED API with your API key
fred = Fred(api_key=os.getenv('fred_api_key'))

# %%
fred.search('S&P', order_by='popularity').head()
# Out:
#                             id realtime_start realtime_end  \
# series id
# BAMLH0A0HYM2      BAMLH0A0HYM2     2026-04-15   2026-04-15
# SP500                    SP500     2026-04-15   2026-04-15
# BAMLC0A0CM          BAMLC0A0CM     2026-04-15   2026-04-15
# BAMLH0A0HYM2EY  BAMLH0A0HYM2EY     2026-04-15   2026-04-15
# CSUSHPINSA          CSUSHPINSA     2026-04-15   2026-04-15
#
#                                                             title  \
# series id
# BAMLH0A0HYM2    ICE BofA US High Yield Index Option-Adjusted S...
# SP500                                                     S&P 500
# BAMLC0A0CM      ICE BofA US Corporate Index Option-Adjusted Sp...
# BAMLH0A0HYM2EY       ICE BofA US High Yield Index Effective Yield
# CSUSHPINSA      S&P Cotality Case-Shiller U.S. National Home P...
#
#                observation_start observation_end     frequency  \
# series id
# BAMLH0A0HYM2          1996-12-31      2026-04-14  Daily, Close
# SP500                 2016-04-15      2026-04-14  Daily, Close
# BAMLC0A0CM            1996-12-31      2026-04-14  Daily, Close
# BAMLH0A0HYM2EY        1996-12-31      2026-04-14  Daily, Close
# CSUSHPINSA            1987-01-01      2026-01-01       Monthly
#
#                frequency_short               units         units_short  \
# series id
# BAMLH0A0HYM2                 D             Percent                   %
# SP500                        D               Index               Index
# BAMLC0A0CM                   D             Percent                   %
# BAMLH0A0HYM2EY               D             Percent                   %
# CSUSHPINSA                   M  Index Jan 2000=100  Index Jan 2000=100
#
#                     seasonal_adjustment seasonal_adjustment_short  \
# series id
# BAMLH0A0HYM2    Not Seasonally Adjusted                       NSA
# SP500           Not Seasonally Adjusted                       NSA
# BAMLC0A0CM      Not Seasonally Adjusted                       NSA
# BAMLH0A0HYM2EY  Not Seasonally Adjusted                       NSA
# CSUSHPINSA      Not Seasonally Adjusted                       NSA
#
#                              last_updated popularity  \
# series id
# BAMLH0A0HYM2    2026-04-15 09:00:33-05:00        100
# SP500           2026-04-14 19:02:08-05:00         91
# BAMLC0A0CM      2026-04-15 09:01:35-05:00         86
# BAMLH0A0HYM2EY  2026-04-15 09:00:32-05:00         85
# CSUSHPINSA      2026-03-31 08:14:32-05:00         84
#
#                                                             notes
# series id
# BAMLH0A0HYM2    Starting in April 2026, this series will only ...
# SP500           The observations for the S&P 500 represent the...
# BAMLC0A0CM      Starting in April 2026, this series will only ...
# BAMLH0A0HYM2EY  Starting in April 2026, this series will only ...
# CSUSHPINSA      For more information regarding the index, plea...
